# %%
import pandas as pd

# %%
data = pd.read_csv("astronautas.csv")
data
# Out:
#                      nombre     genero  anio_nacimiento  \
# 0          Aleksandr Kaleri  masculino             1956
# 1          Yuri Malenchenko  masculino             1961
# 2          Yuri Malenchenko  masculino             1961
# 3      Catherine G. Coleman   femenino             1960
# 4            Chris Hadfield  masculino             1959
# ..                      ...        ...              ...
# 152  Anne Charlotte McClain   femenino             1979
# 153          Christina Koch   femenino             1979
# 154           Andrew Morgan  masculino             1976
# 155            Jessica Meir   femenino             1977
# 156      Hazzaa Al Mansoori  masculino             1983
#
#                nacionalidad   status                       ocupacion  \
# 0             U.S.S.R/Rusia    civil          ingeniero aeroespacial
# 1             U.S.S.R/Rusia  militar                      comandante
# 2             U.S.S.R/Rusia  militar                      comandante
# ...
